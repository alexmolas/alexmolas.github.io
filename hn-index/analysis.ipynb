# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("leaders-output.csv")

# %%
df["karma"].min()
# Out:
# 43785

# %%
plt.plot(df["karma"], df["h index"], 'o')
# plt.plot(df["karma"], np.sqrt(df["karma"]))
plt.xlim
